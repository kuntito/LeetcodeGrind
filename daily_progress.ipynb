# %% [markdown]
# 22-feb-26
# * leetcode (29 mins)
#   * tackled:
#     * [n queens](https://leetcode.com/problems/n-queens/description/)
#
# @tempo0809  @dansong
#
#
# **-feb-26
# * leetcode (** mins)
#   * tackled:
#     * []()
#
# @tempo0809  @dansong
