# %% [markdown]
# 06-feb-26
# * leetcode (2x15 mins)
#   * tackled:
#     * [permutations](https://leetcode.com/problems/permutations/)
#
# @tempo0809  @dansong
#
#
# **-feb-26
# * leetcode (** mins)
#   * tackled:
#     * []()
#
# @tempo0809  @dansong
