# %% [markdown]
# 18-feb-26
# * leetcode (45 mins)
#   * tackled:
#     * [LFU cache](https://leetcode.com/problems/lfu-cache/)
#
# @tempo0809  @dansong
#
#
# **-feb-26
# * leetcode (** mins)
#   * tackled:
#     * []()
#
# @tempo0809  @dansong
