# %% [markdown]
# 16-mar-26
# * leetcode (20 mins)
#   * tackled:
#     * [find in mountain array](https://leetcode.com/problems/find-in-mountain-array/description/)
#
# @tempo0809 @mmk2116
#
# **-mar-26
# * leetcode (20 mins)
#   * tackled:
#     * []()
#
# @tempo0809 @mmk2116
