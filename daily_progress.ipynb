# %% [markdown]
# 28-mar-26
# * leetcode (20 mins)
#     * [n queens ii](https://leetcode.com/problems/n-queens-ii/description/)
#
# @tempo0809 @mmk2116 @rajan3389
#
# **-mar-26
# * leetcode (20 mins)
#     * []()
#
# @tempo0809 @mmk2116 @rajan3389
