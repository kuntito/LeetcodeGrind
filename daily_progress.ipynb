# %% [markdown]
# 06-may-26
# * leetcode (3x20 mins)
#     * [split array largest sum](https://leetcode.com/problems/split-array-largest-sum/)
#
# @zhumphr @indeancondor
#
# **-may-26
# * leetcode (20 mins)
#     * []()
#
# @zhumphr @indeancondor
