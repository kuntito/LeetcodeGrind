# %% [markdown]
# 03-jun-26
# * leetcode (20 mins)
#     * [find kth smallest pair distance](https://leetcode.com/problems/find-k-th-smallest-pair-distance/description/)
#
#
# **-may-26
# * leetcode (20 mins)
#     * []()
