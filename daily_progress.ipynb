# %% [markdown]
# 17-mar-26
# * leetcode (20 mins)
#   * tackled:
#     * [LFU cache](https://leetcode.com/problems/lfu-cache/)
#
# @tempo0809 @mmk2116
#
# **-mar-26
# * leetcode (20 mins)
#   * tackled:
#     * []()
#
# @tempo0809 @mmk2116
