# %% [markdown]
# 14-mar-26
# * leetcode (20 mins)
#   * tackled:
#     * [split array largest sum](https://leetcode.com/problems/split-array-largest-sum/)
#
# @tempo0809 @mmk2116
#
# **-mar-26
# * leetcode (** mins)
#   * tackled:
#     * []()
#
# @tempo0809 @mmk2116
